# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("E:\Store Performance Analysis\Store_Performace.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  Store_ID Store_Location  Store_Area  Monthly_Sales  \
# 0           0      1102        Chicago        1700         132507
# 1           1      1435    Los Angeles        3219         194272
# 2           2      1860        Phoenix        1370          72927
# 3           3      1270       New York        2732          62050
# 4           4      1106        Houston        4226          44232
#
#    Foot_Traffic  Employee_Count  Customer_Ratings  Product_Count  Promotions  \
# 0          1215               6               4.2            494           3
# 1          4430              35               2.3            234           2
# 2          4996              35               3.4            339           6
# 3          4825              20               2.8            269           4
# 4          3893              41               2.1            257           3
#
#    Inventory_Turnover
# 0                1.33
# 1                0.87
# 2                1.72
# ...

# %%
data.drop(["Unnamed: 0"],axis = 1,inplace = True)

# %%
data
# Out:
#        Store_ID Store_Location  Store_Area  Monthly_Sales  Foot_Traffic  \
# 0          1102        Chicago        1700         132507          1215
# 1          1435    Los Angeles        3219         194272          4430
# 2          1860        Phoenix        1370          72927          4996
# 3          1270       New York        2732          62050          4825
# 4          1106        Houston        4226          44232          3893
# ...         ...            ...         ...            ...           ...
# 19995      1884        Houston        4933         174195          3847
# 19996      1796       New York        3735          65450          2036
# 19997      1001        Chicago        2377         118111          2068
# 19998      1232    Los Angeles        3517         103702          3244
# 19999      1368        Phoenix        1724          89926          3241
#
#        Employee_Count  Customer_Ratings  Product_Count  Promotions  \
# ...

# %%
data["Store_Location"].unique()
# Out:
# array(['Chicago', 'Los Angeles', 'Phoenix', 'New York', 'Houston'],
#       dtype=object)

# %%
data.head()
# Out:
#    Store_ID Store_Location  Store_Area  Monthly_Sales  Foot_Traffic  \
# 0      1102        Chicago        1700         132507          1215
# 1      1435    Los Angeles        3219         194272          4430
# 2      1860        Phoenix        1370          72927          4996
# 3      1270       New York        2732          62050          4825
# 4      1106        Houston        4226          44232          3893
#
#    Employee_Count  Customer_Ratings  Product_Count  Promotions  \
# 0               6               4.2            494           3
# 1              35               2.3            234           2
# 2              35               3.4            339           6
# 3              20               2.8            269           4
# 4              41               2.1            257           3
#
#    Inventory_Turnover
# 0                1.33
# 1                0.87
# 2                1.72
# 3                1.40
# 4                0.59

# %%
location_counts = data['Store_Location'].value_counts().sort_values(ascending=False)

# %%
sorted_data = pd.DataFrame({'Store_Location': location_counts.index, 'Count': location_counts.values})

# %%
sns.countplot(data=data, x='Store_Location', order=sorted_data['Store_Location'])
plt.show()

# %%
data.head()
# Out:
#    Store_ID Store_Location  Store_Area  Monthly_Sales  Foot_Traffic  \
# 0      1102        Chicago        1700         132507          1215
# 1      1435    Los Angeles        3219         194272          4430
# 2      1860        Phoenix        1370          72927          4996
# 3      1270       New York        2732          62050          4825
# 4      1106        Houston        4226          44232          3893
#
#    Employee_Count  Customer_Ratings  Product_Count  Promotions  \
# 0               6               4.2            494           3
# 1              35               2.3            234           2
# 2              35               3.4            339           6
# 3              20               2.8            269           4
# 4              41               2.1            257           3
#
#    Inventory_Turnover
# 0                1.33
# 1                0.87
# 2                1.72
# 3                1.40
# 4                0.59

# %%
data.columns
# Out:
# Index(['Store_ID', 'Store_Location', 'Store_Area', 'Monthly_Sales',
#        'Foot_Traffic', 'Employee_Count', 'Customer_Ratings', 'Product_Count',
#        'Promotions', 'Inventory_Turnover'],
#       dtype='object')

# %%
data.drop(["Store_ID","Store_Location"],axis = 1 ,inplace = True)

# %%
data.head()
# Out:
#    Store_Area  Monthly_Sales  Foot_Traffic  Employee_Count  Customer_Ratings  \
# 0        1700         132507          1215               6               4.2
# 1        3219         194272          4430              35               2.3
# 2        1370          72927          4996              35               3.4
# 3        2732          62050          4825              20               2.8
# 4        4226          44232          3893              41               2.1
#
#    Product_Count  Promotions  Inventory_Turnover
# 0            494           3                1.33
# 1            234           2                0.87
# 2            339           6                1.72
# 3            269           4                1.40
# 4            257           3                0.59

# %%
sns.scatterplot(x="Customer_Ratings", y = "Inventory_Turnover",data = data)
# Out:
# <Axes: xlabel='Customer_Ratings', ylabel='Inventory_Turnover'>

# %%
data.head()
# Out:
#    Store_Area  Monthly_Sales  Foot_Traffic  Employee_Count  Customer_Ratings  \
# 0        1700         132507          1215               6               4.2
# 1        3219         194272          4430              35               2.3
# 2        1370          72927          4996              35               3.4
# 3        2732          62050          4825              20               2.8
# 4        4226          44232          3893              41               2.1
#
#    Product_Count  Promotions  Inventory_Turnover
# 0            494           3                1.33
# 1            234           2                0.87
# 2            339           6                1.72
# 3            269           4                1.40
# 4            257           3                0.59

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
tsd = []
for  k in range(1,12):
    kmeans = KMeans(n_clusters = k)
    kmeans.fit(data)
    tsd.append(kmeans.inertia_)


tsd
# Out:
# [60724177521151.3,
#  15059677649008.559,
#  6789980090717.517,
#  3819499357987.5693,
#  2434244819790.708,
#  1735089512552.5789,
#  1295965299419.8057,
#  998130102140.0247,
#  807856537152.0308,
#  656655432317.8374,
#  564203841675.5325]

# %%
plt.figure(figsize=(10, 6)) 
sns.lineplot(x = np.arange(1,12), y = tsd)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
kmeans = KMeans()
kmeans
# Out:
# KMeans()

# %%
kmeans = KMeans(n_clusters = 4)
kmeans.fit(data)
kmeans.inertia_
# Out:
# 3819549532745.6133

# %%
#kmeans.predict(data)

# %%
data
# Out:
#        Store_Area  Monthly_Sales  Foot_Traffic  Employee_Count  \
# 0            1700         132507          1215               6
# 1            3219         194272          4430              35
# 2            1370          72927          4996              35
# 3            2732          62050          4825              20
# 4            4226          44232          3893              41
# ...           ...            ...           ...             ...
# 19995        4933         174195          3847              19
# 19996        3735          65450          2036              18
# 19997        2377         118111          2068              15
# 19998        3517         103702          3244              33
# 19999        1724          89926          3241              22
#
#        Customer_Ratings  Product_Count  Promotions  Inventory_Turnover  \
# 0                   4.2            494           3                1.33
# ...

# %%
data["Clusters_N"] = data["Clusters"]+1

# %%
data
# Out:
#        Store_Area  Monthly_Sales  Foot_Traffic  Employee_Count  \
# 0            1700         132507          1215               6
# 1            3219         194272          4430              35
# 2            1370          72927          4996              35
# 3            2732          62050          4825              20
# 4            4226          44232          3893              41
# ...           ...            ...           ...             ...
# 19995        4933         174195          3847              19
# 19996        3735          65450          2036              18
# 19997        2377         118111          2068              15
# 19998        3517         103702          3244              33
# 19999        1724          89926          3241              22
#
#        Customer_Ratings  Product_Count  Promotions  Inventory_Turnover  \
# 0                   4.2            494           3                1.33
# ...

# %%
data["Clusters"].value_counts()
# Out:
# Clusters
# 1    5175
# 3    5032
# 0    4953
# 2    4840
# Name: count, dtype: int64

# %%
data["Clusters_N"].value_counts()
# Out:
# Clusters_N
# 2    5175
# 4    5032
# 1    4953
# 3    4840
# Name: count, dtype: int64

# %%
data[data["Clusters_N"] == 1].describe()
# Out:
#         Store_Area  Monthly_Sales  Foot_Traffic  Employee_Count  \
# count  4953.000000    4953.000000   4953.000000     4953.000000
# mean   2977.609933   78734.022613   2709.694529       27.187967
# std    1151.431957   13585.391181   1315.304213       13.024768
# min    1000.000000   55649.000000    500.000000        5.000000
# 25%    1985.000000   66749.000000   1563.000000       16.000000
# 50%    2971.000000   78453.000000   2675.000000       27.000000
# 75%    3963.000000   90633.000000   3876.000000       39.000000
# max    4999.000000  102729.000000   4999.000000       49.000000
#
#        Customer_Ratings  Product_Count   Promotions  Inventory_Turnover  \
# count       4953.000000    4953.000000  4953.000000         4953.000000
# mean           2.975167     276.197456     4.538260            1.260371
# std            1.145167     129.603114     2.867602            0.430343
# min            1.000000      50.000000     0.000000            0.500000
# ...

# %%
data[data["Clusters_N"] == 2].describe()
# Out:
#         Store_Area  Monthly_Sales  Foot_Traffic  Employee_Count  \
# count  5175.000000    5175.000000   5175.000000     5175.000000
# mean   3032.345507  175520.529855   2747.805411       26.898357
# std    1161.050494   14158.093887   1303.390355       13.045981
# min    1000.000000  151155.000000    501.000000        5.000000
# 25%    2033.000000  163358.500000   1607.000000       16.000000
# 50%    3047.000000  175795.000000   2749.000000       27.000000
# 75%    4044.000000  187768.500000   3873.000000       38.000000
# max    4999.000000  199981.000000   4999.000000       49.000000
#
#        Customer_Ratings  Product_Count   Promotions  Inventory_Turnover  \
# count       5175.000000    5175.000000  5175.000000         5175.000000
# mean           3.009546     273.892174     4.449662            1.261957
# std            1.162479     129.048715     2.849757            0.428394
# min            1.000000      50.000000     0.000000            0.500000
# ...

# %%
data[data["Clusters_N"] == 3].describe()
# Out:
#         Store_Area  Monthly_Sales  Foot_Traffic  Employee_Count  \
# count  4840.000000    4840.000000   4840.000000     4840.000000
# mean   3036.901240   32618.354132   2729.703926       27.319215
# std    1153.155975   13118.794451   1309.342777       12.992151
# min    1001.000000   10002.000000    500.000000        5.000000
# 25%    2037.000000   21223.500000   1578.000000       16.000000
# 50%    3052.000000   32745.500000   2722.500000       27.000000
# 75%    4039.500000   43722.500000   3852.500000       39.000000
# max    4999.000000   55621.000000   4998.000000       49.000000
#
#        Customer_Ratings  Product_Count   Promotions  Inventory_Turnover  \
# count       4840.000000    4840.000000  4840.000000         4840.000000
# mean           3.004876     273.340496     4.518182            1.257566
# std            1.170805     129.808582     2.860698            0.439485
# min            1.000000      50.000000     0.000000            0.500000
# ...

# %%
data[data["Clusters_N"] == 4].describe()
# Out:
#         Store_Area  Monthly_Sales  Foot_Traffic  Employee_Count  \
# count  5032.000000    5032.000000   5032.000000     5032.000000
# mean   2980.018680  126820.365461   2747.811010       27.129571
# std    1155.206909   13917.123619   1300.703007       13.000447
# min    1000.000000  102767.000000    500.000000        5.000000
# 25%    1963.750000  114664.750000   1618.000000       16.000000
# 50%    2998.000000  126860.000000   2738.500000       27.000000
# 75%    3975.000000  138632.250000   3855.000000       38.000000
# max    4999.000000  151141.000000   4999.000000       49.000000
#
#        Customer_Ratings  Product_Count   Promotions  Inventory_Turnover  \
# count       5032.000000    5032.000000  5032.000000         5032.000000
# mean           2.963971     272.910771     4.429849            1.259275
# std            1.160658     130.335015     2.896246            0.436168
# min            1.000000      50.000000     0.000000            0.500000
# ...

# %% [markdown]
# __Silhouette Score:__
#
# __Measures how similar a data point is to its own cluster compared to other clusters. Values range from -1 to 1, where a higher value indicates better clustering.__

# %%
from sklearn.metrics import silhouette_score

# Assuming 'Clusters' is your clustering result
silhouette_avg = silhouette_score(data, data['Clusters'])
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.5649590031186998

# %% [markdown]
# __Davies-Bouldin Index:__
#
# __Measures the average similarity ratio of each cluster with its most similar cluster. Lower values indicate better clustering.__

# %%
from sklearn.metrics import davies_bouldin_score

db_index = davies_bouldin_score(data, data['Clusters'])
print(f"Davies-Bouldin Index: {db_index}")
# Out:
# Davies-Bouldin Index: 0.5105645869876314

# %% [markdown]
# __Measures the ratio of the sum of between-cluster dispersion to within-cluster dispersion. Higher values indicate better clustering.__

# %%
from sklearn.metrics import calinski_harabasz_score

ch_index = calinski_harabasz_score(data, data['Clusters'])
print(f"Calinski-Harabasz Index: {ch_index}")
# Out:
# Calinski-Harabasz Index: 99302.49480282357
